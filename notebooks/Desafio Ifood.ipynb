# %% [markdown]
# # Desafio Ifood

# %% [markdown]
# O conjunto de dados é composto por clientes da empresa Ifood com dados sobre:
#
# - Perfis de clientes
# - Preferências do produto
# - Sucessos/fracassos da campanha
# - Desempenho do canal

# %%
# Importando bibliotecas úteis para análise
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Caminho csv
path = 'C:/Users/João Henrique/Documents/Projetos/Desafio-Ifood/data/mkt_data.csv'

# %%
# Lendo csv
df = pd.read_csv(path)

# %%
# Mostrando o DataFrame
df
# Out:
#       Unnamed: 0   Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0              0  58138.0        0         0       58       635         88
# 1              1  46344.0        1         1       38        11          1
# 2              2  71613.0        0         0       26       426         49
# 3              3  26646.0        1         0       26        11          4
# 4              4  58293.0        1         0       94       173         43
# ...          ...      ...      ...       ...      ...       ...        ...
# 2200        2200  61223.0        0         1       46       709         43
# 2201        2201  64014.0        2         1       56       406          0
# 2202        2202  56981.0        0         0       91       908         48
# 2203        2203  69245.0        0         1        8       428         30
# 2204        2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  ...  \
# ...

# %%
# Dropando a coluna Unnamed: 0
df = df.drop("Unnamed: 0", axis=1)

# %%
# Retirando os itens duplicados
df = df.drop_duplicates()

# %%
# Mostrando df atualizado
df
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0     58138.0        0         0       58       635         88
# 1     46344.0        1         1       38        11          1
# 2     71613.0        0         0       26       426         49
# 3     26646.0        1         0       26        11          4
# 4     58293.0        1         0       94       173         43
# ...       ...      ...       ...      ...       ...        ...
# 2198  26816.0        0         0       50         5          1
# 2200  61223.0        0         1       46       709         43
# 2202  56981.0        0         0       91       908         48
# 2203  69245.0        0         1        8       428         30
# 2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %% [markdown]
# O objetivo é fazer uma análise exploratória dos dados. Vamos primeiro responder as seguintes perguntas:
#
# - Quantos dados temos? Linhas e colunas
# - Quais são as colunas numéricas?
# - Temos duplicados na nossa base? Se tivermos, retire-os
# - Temos dados nulos nessa base? Será que eles indicam algo? O que fazer com eles?
# - Qual é a média, mediana, 25 percentil, 75 percentil, mínimo e máximo de cada uma das colunas numéricas?

# %% [markdown]
# ## Quantos dados temos? Linhas e colunas

# %%
# Usando shape para ver as linhas x colunas
df.shape
# Out:
# (2021, 43)

# %% [markdown]
# Podemos observar que temos 2021 linhas e 43 colunas

# %% [markdown]
# ## Quais são as colunas numéricas?

# %%
# Usando info() para verificar as colunas numéricas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2021 entries, 0 to 2204
# Data columns (total 43 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Income                2021 non-null   float64
#  1   Kidhome               2021 non-null   int64
#  2   Teenhome              2021 non-null   int64
#  3   Recency               2021 non-null   int64
#  4   MntWines              2021 non-null   int64
#  5   MntFruits             2021 non-null   int64
#  6   MntMeatProducts       2021 non-null   int64
#  7   MntFishProducts       2021 non-null   int64
#  8   MntSweetProducts      2021 non-null   int64
#  9   MntGoldProds          2021 non-null   int64
#  10  NumDealsPurchases     2021 non-null   int64
#  11  NumWebPurchases       2021 non-null   int64
#  12  NumCatalogPurchases   2021 non-null   int64
#  13  NumStorePurchases     2021 non-null   int64
#  14  NumWebVisitsMonth     2021 non-null   int64
# ...

# %% [markdown]
# As colunas numéricas são aquelas que possuem o Dtype igual a int64 e float64. Podemos observar que 11 colunas são float64 e 31 colunas int64.

# %% [markdown]
# ## Temos duplicados na nossa base? Se tivermos, retire-os

# %%
# Verificando se temos dados duplicados
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Nossos dados não possuem valores duplicados.

# %% [markdown]
# ## Temos dados nulos nessa base? Será que eles indicam algo? O que fazer com eles?

# %%
# Verificando se temos dados nulos
df.isna().sum()
# Out:
# Income                     0
# Kidhome                    0
# Teenhome                   0
# Recency                    0
# MntWines                   0
# MntFruits                  0
# MntMeatProducts            0
# MntFishProducts            0
# MntSweetProducts           0
# MntGoldProds               0
# NumDealsPurchases          0
# NumWebPurchases            0
# NumCatalogPurchases        0
# NumStorePurchases          0
# NumWebVisitsMonth          0
# AcceptedCmp3               0
# AcceptedCmp4               0
# AcceptedCmp5               0
# AcceptedCmp1               0
# AcceptedCmp2               0
# Complain                   0
# Z_CostContact              0
# Z_Revenue                  0
# Response                   0
# Age                        0
# Customer_Days              0
# marital_Divorced        1807
# marital_Married         1236
# marital_Single          1578
# marital_Together        1512
# marital_Widow           1951
# education_2n Cycle      1838
# ...

# %% [markdown]
# Podemos ver que algumas colunas possuem valores nulos. As colunas que apresentam dados nulos são:
#
# - marital_Divorced
# - marital_Married
# - marital_Single
# - marital_Together
# - marital_Widow
# - education_2n Cycle
# - education_Basic
# - education_Graduation
# - education_Master
# - education_PhD
#
# Os nulos acima podem indicar que tal característica não faz parte daquela pessoa. Por exemplo, uma pessoa divorciada
# tem um determinado valor ou um valor nulo

# %%
# Contando os valores únicos de uma das colunas nulas. 
df["marital_Divorced"].value_counts()
# Out:
# marital_Divorced
# 1.0    214
# Name: count, dtype: int64

# %% [markdown]
# Observando a coluna marital_Divorced, vemos que ela possuí apenas o número 1.0 que aparece 214 vezes, e o resto dos valores são nulos.
# Isso é um indício que o nulo significa que a pessoa não possuí aquela determinada variável.

# %% [markdown]
# Podemos substituir o NaN (valores nulos) pelos valores 0 para faltante e 1 para presente.

# %%
colunas_com_nulos = [
    "marital_Divorced",
    "marital_Married",
    "marital_Single",
    "marital_Together",
    "marital_Widow",
    "education_2n Cycle",
    "education_Basic",
    "education_Graduation",
    "education_Master",
    "education_PhD"
]

for coluna in colunas_com_nulos:
    df[coluna] = np.where(pd.isna(df[coluna]), 0, 1)

# %%
df
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0     58138.0        0         0       58       635         88
# 1     46344.0        1         1       38        11          1
# 2     71613.0        0         0       26       426         49
# 3     26646.0        1         0       26        11          4
# 4     58293.0        1         0       94       173         43
# ...       ...      ...       ...      ...       ...        ...
# 2198  26816.0        0         0       50         5          1
# 2200  61223.0        0         1       46       709         43
# 2202  56981.0        0         0       91       908         48
# 2203  69245.0        0         1        8       428         30
# 2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %% [markdown]
# ## Qual é a média, mediana, 25 percentil, 75 percentil, mínimo e máximo de cada uma das colunas numéricas?

# %%
# Utilizando describe para ver as medidas estatísticas
df.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2021.000000  2021.000000  2021.000000  2021.000000  2021.000000
# mean    51687.258783     0.443345     0.509649    48.880752   306.492331
# std     20713.046401     0.536196     0.546393    28.950917   337.603877
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35416.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51412.000000     0.000000     0.000000    49.000000   178.000000
# 75%     68274.000000     1.000000     1.000000    74.000000   507.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2021.000000      2021.000000      2021.000000       2021.000000
# mean     26.364671       166.059871        37.603662         27.268679
# std      39.776518       219.869126        54.892196         41.575454
# ...

# %% [markdown]
# A média é representada pela linha mean, a mediana pelos 50%, 25 percentil por 25%, 75 percentil por 75%, mínimo pelo min e máximo pelo max.

# %% [markdown]
# Vamos agora entender o perfil de clientes que temos
#
# - Qual é o maior salário encontrado na nossa base?
# - Qual é a distribuição de salário na nossa base? Temos clientes que ganham muito bem e outros que não ganham muito bem?
# - Nossos clientes tem níveis de educação maiores ou menores?
# - Quantos clientes temos em cada estado civil?

# %% [markdown]
# ## Qual é o maior salário encontrado na nossa base?

# %%
df["Income"].max()
# Out:
# np.float64(113734.0)

# %% [markdown]
# O maior salário encontrado na nossa base é de 113.734

# %% [markdown]
# ## Qual é a distribuição de salário na nossa base? Temos clientes que ganham muito bem e outros que não ganham muito bem?

# %%
# Criando o histograma
sns.histplot(x=df["Income"], bins=10);

# %%
# Criando um boxplot
sns.boxplot(df["Income"]);

# %% [markdown]
# Além de verificar o histograma e o boxplot, vamos cálcular o coeficiente de variação e o skew.
#
# O coeficiente de variação é interessante pois não está atrelado a uma unidade de medida então não precisamos ter ideia da grandeza da média para
# entender se o valor é grande ou pequeno. O CV pode ser dado em decimal ou porcentagem.
#
# O skew é a assimetria da distribuição dos dados em relação a sua média, o skew mostra de uma forma numérica onde está a assimetria dos nossos dados.
# Dizemos que os dados são aproximadamente normais (simétricos) se -1 < Skew < 1.

# %%
# Calculando o Coeficiente de Variação
# Quanto mais próximo de 1 (100%) mais disperso os dados são
# em relação à média.
df["Income"].std()/df["Income"].mean()
# Out:
# np.float64(0.4007379553227728)

# %%
# Calculando o skew (assimetria) da distribuição dos dados
df["Income"].skew()
# Out:
# np.float64(0.004357040710783565)

# %% [markdown]
# Com base nas análises acima, podemos ver que temos uma boa distribuição dos dados, focando no skew podemos ver que temos aproximadamente uma normal.
# Podemos ver também que poucas pessoas ganham pouco e poucas pessoas ganham muito.

# %% [markdown]
# ## Nossos clientes tem níveis de educação maiores ou menores?

# %%
# Criando histograma
sns.countplot(x=df["education_level"]);

# %% [markdown]
# A maioria dos nossos clientes possuem ensino superior.

# %% [markdown]
# ## Quantos clientes temos em cada estado civil?

# %%
# Criando histograma
sns.countplot(x=df['marital_status']);

# %% [markdown]
# A maior parte dos nossos cliente são casados (Married) ou moram junto (Together). Poucos são viúvos.

# %% [markdown]
# Agora vamos ver como os dados se correlacionam
#
# - Qual é a relação de estado civil com número de filhos? Será que as pessoas casadas têm um maior número de filhos?
# - As pessoas gastam mais ou menos em nossa plataforma quando têm filhos?
# - Pessoas que têm um maior salário gastam mais?

# %% [markdown]
# ## Qual é a relação de estado civil com número de filhos? Será que as pessoas casadas têm um maior número de filhos?

# %%
# Plotando um boxplot
sns.boxplot(x='marital_status', y='kids', data=df)
# Out:
# <Axes: xlabel='marital_status', ylabel='kids'>

# %%
df.groupby('marital_status')['kids'].describe()
# Out:
#                 count      mean       std  min  25%  50%  75%  max
# marital_status
# Divorced        214.0  1.023364  0.753344  0.0  1.0  1.0  1.0  3.0
# Married         785.0  0.977070  0.724558  0.0  0.0  1.0  1.0  3.0
# Single          443.0  0.860045  0.771850  0.0  0.0  1.0  1.0  3.0
# Together        509.0  0.982318  0.748806  0.0  0.0  1.0  1.0  3.0
# Widow            70.0  0.842857  0.734960  0.0  0.0  1.0  1.0  2.0

# %% [markdown]
# Media de filhos por status de união

# %%
df.groupby('marital_status')['kids'].mean()
# Out:
# marital_status
# Divorced    1.023364
# Married     0.977070
# Single      0.860045
# Together    0.982318
# Widow       0.842857
# Name: kids, dtype: float64

# %% [markdown]
# Mediana de filhos por status de união

# %%
df.groupby('marital_status')['kids'].median()
# Out:
# marital_status
# Divorced    1.0
# Married     1.0
# Single      1.0
# Together    1.0
# Widow       1.0
# Name: kids, dtype: float64

# %% [markdown]
# Apesar dos números bem próximos podemos ver que tanto os solteiros (Single) quanto os viúvos (Widow) são os que possuem menores
# quantidade de filhos, isso fica mais evidente quando olhamos para a média.
#
# Olhando apenas para a quantidade, vemos que sim as pessoas casadas são as que possuem maior número de filhos.

# %% [markdown]
# ## As pessoas gastam mais ou menos em nossa plataforma quando têm filhos?

# %%
# Relação entre maior ou menor gasto e número de filhos
sns.boxplot(data=df, x='kids', y='expenses')
# Out:
# <Axes: xlabel='kids', ylabel='expenses'>

# %% [markdown]
# Média entre quantidade de filhos e gastos na plataforma

# %%
df.groupby('kids')['expenses'].mean()
# Out:
# kids
# 0    1056.282187
# 1     432.732230
# 2     223.267016
# 3     240.044444
# Name: expenses, dtype: float64

# %% [markdown]
# Mediana entre quantidade de filhos e gastos na plataforma

# %%
df.groupby('kids')['expenses'].median()
# Out:
# kids
# 0    1114.0
# 1     265.0
# 2      84.0
# 3      62.0
# Name: expenses, dtype: float64

# %% [markdown]
# Vendo a média, mediana e o boxplot, conseguimos chegar a conclusão de que não necessariamente quem tem mais filhos gasta mais.
# Vemos que quem não possuí filho gasta bem mais na plataforma do que quem possuí, porém, as pessoas que possuem 1 único filho
# também gastam uma quantia considerável. Pessoas com 2+ filhos quase não gastam na plataforma.

# %% [markdown]
# ## Pessoas que têm um maior salário gastam mais?

# %%
# Plotando gráfico de dispersão
sns.scatterplot(x='expenses', y='Income', data=df)
# Out:
# <Axes: xlabel='expenses', ylabel='Income'>

# %% [markdown]
# Aparentemente temos um correlação, onde as pessoas que ganham mais acabam por gastar mais.
